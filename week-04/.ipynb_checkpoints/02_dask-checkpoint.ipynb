# %% [markdown]
# # Hands-On: Dask
#
# ## 1. Follow the 10 Minutes to Dask tutorial:
# https://docs.dask.org/en/stable/10-minutes-to-dask.html
#
# You can do this on your local machine.
# Dask needs to be installed as follows:
# https://docs.dask.org/en/stable/install.html

# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %% [markdown]
# ## 2. Follow the longer Dask SciPy22 tutorial: https://github.com/dask/dask-tutorial/
